# %% [markdown]
# # **Project Name**    - Flipkart

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.
# Introduction
#
# In today’s customer-centric business environment, delivering efficient and high-quality support services is crucial for retaining customers and building brand loyalty. This project analyzes customer support data to identify trends, optimize response and resolution times, and enhance customer satisfaction (CSAT Score). By leveraging data visualization and statistical insights, we provide actionable recommendations to improve customer service operations.
#
# Data Wrangling & Preprocessing
#
# Before analysis, the dataset was cleaned and prepared for insights. The key steps included:
#
# ✔ Handling missing values by either dropping or imputing where necessary.
#
# ✔ Standardizing column names to maintain consistency.
#
# ✔ Converting date fields to a proper datetime format for trend analysis.
#
# ✔ Removing anomalies in resolution times and extreme CSAT scores.
#
# By performing these data cleaning steps, we ensured a structured and error-free dataset, enabling accurate analysis.
#
# Key Insights from Data Analysis
#
# 1️⃣ Issues by Category
# The majority of customer issues fall under specific categories, indicating recurring problems that need to be addressed. Businesses should focus on resolving frequently reported issues to enhance service quality.
#
# 2️⃣ CSAT Score Distribution
# Most customer satisfaction scores are in the 3–4 range, suggesting room for improvement in service quality. Strategies like better agent training and proactive communication can help boost scores.
#
# 3️⃣ Resolution Time vs. CSAT Score
# There is a clear negative correlation between resolution time and CSAT scores—longer resolution times lead to lower customer satisfaction. Reducing resolution time should be a priority to improve the overall customer experience.
#
# 4️⃣ Issue Resolution Time Trends
# Certain issue categories have significantly higher resolution times, suggesting inefficiencies in handling specific cases. Businesses should investigate these categories to streamline processes.
#
# 5️⃣ Support Channel Effectiveness
# Different support channels (email, chat, phone) handle varying case volumes. Live chat and phone support tend to be faster but require more agents. Balancing resources across channels is crucial for better efficiency.
#
# 6️⃣ Top-Performing Agents
# The top 10 agents handle most of the cases, which may indicate expertise concentration or workload imbalance. Training more agents to handle complex issues can improve overall performance.
#
# 7️⃣ CSAT Score by Issue Category
# Some categories consistently receive lower CSAT scores, indicating customer dissatisfaction in specific areas. These categories need process improvements or better support mechanisms.
#
# 8️⃣ Handling Time by Category
# A few issue categories take significantly longer to resolve. Introducing automation, self-service options, or AI-driven chatbots can help reduce handling time for these complex issues.
#
# 9️⃣ Issue Response Time vs. CSAT
# A scatterplot analysis with a trend line confirms that faster response times correlate with higher CSAT scores. Businesses should optimize initial response processes to minimize waiting times.
#
# 🔟 Correlation Between Numeric Variables
# A heatmap analysis shows that CSAT scores do not have a strong correlation with item prices, meaning pricing alone does not determine customer satisfaction—service quality matters more.
#
# 1️⃣1️⃣ Geographic Analysis of Customer Issues
# Certain cities report more issues, suggesting regional service quality gaps. Businesses should analyze local factors, such as agent availability and service infrastructure, to improve customer experiences.
#
# 1️⃣2️⃣ CSAT Trend Over Time
# There are periodic drops in CSAT scores, likely due to seasonal factors, peak demand times, or operational inefficiencies. Businesses should closely monitor trends and staff accordingly to manage high-demand periods.
#
# Business Recommendations
# ✅ Improve Response and Resolution Times
#
# Optimize workflows and introduce automation tools for faster case resolution.
# Implement chatbots and AI-driven customer support for quick issue handling.
# ✅ Enhance Agent Training & Workload Distribution
#
# Identify training needs for agents handling low CSAT categories.
# Distribute workloads more effectively to avoid agent burnout.
# ✅ Optimize Support Channels
#
# Allocate more resources to popular channels like chat and phone support.
# Introduce self-service FAQs and automated solutions for common issues.
# ✅ Focus on Low CSAT Regions
#
# Identify reasons for higher issue volumes in specific cities.
# Strengthen regional support teams and improve service delivery in those areas.
# ✅ Monitor CSAT Trends for Proactive Support
#
# Use predictive analytics to anticipate customer issues before they escalate.
# Offer personalized solutions based on customer history and common concerns.
# Conclusion
# By analyzing customer interactions, issue resolution trends, and agent performance, this project provides data-driven insights to enhance customer satisfaction. Businesses should focus on reducing resolution time, improving service processes, and optimizing support channels to ensure a seamless customer experience.
#
# Implementing these recommendations will lead to higher CSAT scores, improved customer retention, and increased brand trust, ultimately driving positive business growth.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/kambirereshma88/Labmentix-Project-4-Flipkart-EDA.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
#
# In today's competitive market, providing efficient and high-quality customer support is critical for business success. However, companies often face challenges such as long resolution times, low customer satisfaction (CSAT) scores, inconsistent service quality across different channels, and workload imbalances among support agents.
#
# This project aims to analyze customer support data to:
#
# Identify key factors affecting customer satisfaction.
# Analyze resolution time trends and their impact on CSAT scores.
# Understand which support channels perform best and where improvements are needed.
# Recognize top-performing agents and optimize workload distribution.
# Pinpoint geographic regions with the most customer complaints.
# Provide data-driven recommendations to improve customer experience and business efficiency.
# By addressing these challenges, businesses can enhance their support operations, reduce resolution times, increase customer satisfaction, and ultimately improve brand loyalty and customer retention.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.
#
# The primary objective of this project is to analyze customer support data to enhance customer satisfaction (CSAT), optimize issue resolution processes, and improve business efficiency. By leveraging data-driven insights, the business aims to:
#
# Key Goals:
#
# 1️⃣ Improve Customer Satisfaction (CSAT)
#
# Identify key factors affecting CSAT scores.
# Reduce resolution times to enhance customer experience.
# Optimize service quality across different support channels.
#
# 2️⃣ Optimize Issue Resolution & Support Efficiency
#
# Analyze resolution time patterns to minimize delays.
# Identify workload distribution among agents and optimize resources.
# Enhance first-contact resolution rates.
#
# 3️⃣ Enhance Support Channel Effectiveness
#
# Determine which communication channels (email, chat, phone, etc.) handle the highest volume of issues.
# Improve underperforming channels by addressing service gaps.
#
# 4️⃣ Data-Driven Decision Making
#
# Use visualization and statistical analysis to guide customer support improvements.
# Recognize geographical trends in customer complaints to tailor regional strategies.
# Provide actionable recommendations for better resource allocation and agent training.
#
# By achieving these goals, the company can increase operational efficiency, boost customer loyalty, and gain a competitive advantage in the market.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
df = pd.read_csv("Customer_support_data.csv")

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#                                   Unique id channel_name         category  \
# 0      7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1      b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2      200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3      eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4      ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
# ...                                     ...          ...              ...
# 85902  505ea5e7-c475-4fac-ac36-1d19a4cb610f      Inbound   Refund Related
# 85903  44b38d3f-1523-4182-aba2-72917586647c      Inbound    Order Related
# 85904  723bce2c-496c-4aa8-a64b-ca17004528f0      Inbound    Order Related
# 85905  707528ee-6873-4192-bfa9-a491f1c08ab5      Inbound         Feedback
# 85906  07c7a878-0d5a-42e0-97ef-de59abec0238      Inbound          Returns
#
#                        Sub-category                          Customer Remarks  \
# ...

# %%
display(df.head())
# Out:
#                               Unique id channel_name         category  \
# 0  7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Outcall  Product Queries
# 1  b07ec1b0-f376-43b6-86df-ec03da3b2e16      Outcall  Product Queries
# 2  200814dd-27c7-4149-ba2b-bd3af3092880      Inbound    Order Related
# 3  eb0d3e53-c1ca-42d3-8486-e42c8d622135      Inbound          Returns
# 4  ba903143-1e54-406c-b969-46c52f92e5df      Inbound     Cancellation
#
#                    Sub-category Customer Remarks  \
# 0                Life Insurance              NaN
# 1  Product Specific Information              NaN
# 2             Installation/demo              NaN
# 3        Reverse Pickup Enquiry              NaN
# 4                    Not Needed              NaN
#
#                                Order_id order_date_time Issue_reported at  \
# 0  c27c9bb4-fa36-4140-9f1f-21009254ffdb             NaN  01/08/2023 11:13
# 1  d406b0c7-ce17-4654-b9de-f08d421254bd             NaN  01/08/2023 12:52
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# Dataset Rows & Columns count
print("Dataset Shape:", df.shape)
print("\nNumber of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])
# Out:
# Dataset Shape: (85907, 20)
#
# Number of Rows: 85907
# Number of Columns: 20

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("\nColumn Data Types:")
print(df.dtypes)
# Out:
# Column Data Types:
# Unique id                   object
# channel_name                object
# category                    object
# Sub-category                object
# Customer Remarks            object
# Order_id                    object
# order_date_time             object
# Issue_reported at           object
# issue_responded             object
# Survey_response_Date        object
# Customer_City               object
# Product_category            object
# Item_price                 float64
# connected_handling_time    float64
# Agent_name                  object
# Supervisor                  object
# Manager                     object
# Tenure Bucket               object
# Agent Shift                 object
# CSAT Score                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85907 entries, 0 to 85906
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unique id                85907 non-null  object
#  1   channel_name             85907 non-null  object
#  2   category                 85907 non-null  object
#  3   Sub-category             85907 non-null  object
#  4   Customer Remarks         28742 non-null  object
#  5   Order_id                 67675 non-null  object
#  6   order_date_time          17214 non-null  object
#  7   Issue_reported at        85907 non-null  object
#  8   issue_responded          85907 non-null  object
#  9   Survey_response_Date     85907 non-null  object
#  10  Customer_City            17079 non-null  object
#  11  Product_category         17196 non-null  object
#  12  Item_price               17206 non-null  float64
#  13  connected_handling_time  242 non-null    float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print("\nNumber of Duplicate Rows:", duplicate_count)
# Out:
# Number of Duplicate Rows: 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Unique id                      0
# channel_name                   0
# category                       0
# Sub-category                   0
# Customer Remarks           57165
# Order_id                   18232
# order_date_time            68693
# Issue_reported at              0
# issue_responded                0
# Survey_response_Date           0
# Customer_City              68828
# Product_category           68711
# Item_price                 68701
# connected_handling_time    85665
# Agent_name                     0
# Supervisor                     0
# Manager                        0
# Tenure Bucket                  0
# Agent Shift                    0
# CSAT Score                     0
# dtype: int64

# %%
# Visualizing the missing values
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(12, 6))

# Filter columns with missing values
missing_counts = df.isnull().sum()
missing_counts = missing_counts[missing_counts > 0].sort_values(ascending=False)

# Create a bar plot of missing values
sns.barplot(x=missing_counts.index, y=missing_counts.values, palette="Reds")

# Labels and title
plt.xlabel("Columns")
plt.ylabel("Count of Missing Values")
plt.title("Missing Values in Dataset")
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Answer Here
#
# 1.The dataset has 85,907 rows and 20 columns.
#
# 2.No duplicate values exist.
#
# 3.Many columns have missing values, especially Customer Remarks, Customer_City, and order_date_time.
#
# 4.Some categorical columns may require encoding for machine learning tasks.
#
# 5.Data cleaning is necessary before any analysis or modeling.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# Get dataset columns
print(df.columns)
# Out:
# Index(['Unique id', 'channel_name', 'category', 'Sub-category',
#        'Customer Remarks', 'Order_id', 'order_date_time', 'Issue_reported at',
#        'issue_responded', 'Survey_response_Date', 'Customer_City',
#        'Product_category', 'Item_price', 'connected_handling_time',
#        'Agent_name', 'Supervisor', 'Manager', 'Tenure Bucket', 'Agent Shift',
#        'CSAT Score'],
#       dtype='object')

# %%
# Get statistical summary of numerical & categorical columns
dataset_description = df.describe(include='all')

# %%
# Dataset Describe
print(df.describe())
# Out:
#           Item_price  connected_handling_time    CSAT Score
# count   17206.000000               242.000000  85907.000000
# mean     5660.774846               462.400826      4.242157
# std     12825.728411               246.295037      1.378903
# min         0.000000                 0.000000      1.000000
# 25%       392.000000               293.000000      4.000000
# 50%       979.000000               427.000000      5.000000
# 75%      2699.750000               592.250000      5.000000
# max    164999.000000              1986.000000      5.000000

# %%
print(df.describe(include="all"))
# Out:
#                                    Unique id channel_name category  \
# count                                  85907        85907    85907
# unique                                 85907            3       12
# top     7e9ae164-6a8b-4521-a2d4-58f7c9fff13f      Inbound  Returns
# freq                                       1        68142    44097
# mean                                     NaN          NaN      NaN
# std                                      NaN          NaN      NaN
# min                                      NaN          NaN      NaN
# 25%                                      NaN          NaN      NaN
# 50%                                      NaN          NaN      NaN
# 75%                                      NaN          NaN      NaN
# max                                      NaN          NaN      NaN
#
#                   Sub-category Customer Remarks  \
# count                    85907            28742
# unique                      57            18231
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
# | **Variable Name**       | **Description**                                         | **Data Type**   | **Example Values**          |
# |------------------------|-----------------------------------------------------|---------------|--------------------------|
# | `Issue_ID`             | Unique identifier for each customer issue/ticket    | String        | `TCK12345`, `TCK67890`   |
# | `Customer_ID`          | Unique identifier for each customer                 | String        | `CUST1001`, `CUST2002`   |
# | `Issue_reported at`    | Date and time when the issue was reported           | Datetime      | `2024-01-15 10:30:00`    |
# | `issue_responded`      | Date and time when the support team responded       | Datetime      | `2024-01-15 10:45:00`    |
# | `Resolution_Time`      | Time taken to resolve the issue (in minutes)        | Numeric       | `30`, `120`, `500`       |
# | `Category`             | Type of issue reported by the customer              | Categorical   | `Payment`, `Delivery`, `Product Issue` |
# | `Support_Channel`      | The channel through which the issue was reported    | Categorical   | `Email`, `Phone`, `Chat` |
# | `Agent_ID`            | ID of the support agent handling the issue           | String        | `AG001`, `AG045`         |
# | `CSAT Score`          | Customer Satisfaction Score (1-5 scale)              | Numeric       | `1`, `3`, `5`            |
# | `Customer_City`       | Location of the customer                            | Categorical   | `New York`, `London`, `Delhi` |
# | `Issue_Severity`      | Severity level of the reported issue                | Categorical   | `Low`, `Medium`, `High`  |
# | `Resolution_Status`   | Whether the issue was resolved or not               | Categorical   | `Resolved`, `Unresolved` |
# | `Item_Price`         | Price of the item for which the issue was raised    | Numeric       | `500`, `1200`, `7999`    |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# Count unique values per column
print("Unique Values Per Column:\n", df.nunique())
# Out:
# Unique Values Per Column:
#  Unique id                  85907
# channel_name                   3
# category                      12
# Sub-category                  57
# Customer Remarks           18231
# Order_id                   67675
# order_date_time            13766
# Issue_reported at          30923
# issue_responded            30262
# Survey_response_Date          31
# Customer_City               1782
# Product_category               9
# Item_price                  2789
# connected_handling_time      211
# Agent_name                  1371
# Supervisor                    40
# Manager                        6
# Tenure Bucket                  5
# Agent Shift                    5
# CSAT Score                     5
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Load the dataset
df = pd.read_csv("Customer_support_data.csv")

# Step 1: Handle missing values
df.dropna(inplace=True)  # Drop rows with missing values

# Step 2: Convert date columns to datetime format
date_columns = ['order_date_time', 'Issue_reported at', 'issue_responded', 'Survey_response_Date']
for col in date_columns:
    if col in df.columns:
        df[col] = pd.to_datetime(df[col], errors='coerce')

# Step 3: Convert categorical columns to category type for optimization
categorical_columns = ['channel_name', 'category', 'Sub-category', 'Customer_City', 
                       'Product_category', 'Agent_name', 'Supervisor', 'Manager', 
                       'Tenure Bucket', 'Agent Shift']

for col in categorical_columns:
    if col in df.columns:
        df[col] = df[col].astype('category')

# Step 4: Convert numerical columns to appropriate data types
numerical_columns = ['Item_price', 'connected_handling_time', 'CSAT Score']
for col in numerical_columns:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')


# Step 5: Remove duplicate rows if any
df.drop_duplicates(inplace=True)

# Step 6: Reset index after cleaning
df.reset_index(drop=True, inplace=True)

# Step 7: Generate insights
print("Dataset Shape after Cleaning:", df.shape)

# Step 8: Display unique values count for categorical columns
print("\nUnique Values in Categorical Columns:")
for col in categorical_columns:
    if col in df.columns:
        print(f"{col}: {df[col].nunique()} unique values, Most common: {df[col].mode()[0]}")

# Step 9: Numerical Data Statistics
print("\nNumerical Data Summary:")
print(df[numerical_columns].describe())


# Step 10: Display first few rows after cleaning
print("\nCleaned Dataset Preview:")
print(df.head())
# Out:
# Dataset Shape after Cleaning: (38, 20)
#
# Unique Values in Categorical Columns:
# channel_name: 2 unique values, Most common: Outcall
# category: 3 unique values, Most common: Returns
# Sub-category: 3 unique values, Most common: Return request
# Customer_City: 35 unique values, Most common: BARASAT
# Product_category: 3 unique values, Most common: Electronics
# Agent_name: 24 unique values, Most common: Jennifer Perry
# Supervisor: 9 unique values, Most common: Mason Gupta
# Manager: 3 unique values, Most common: Olivia Tan
# Tenure Bucket: 3 unique values, Most common: >90
# Agent Shift: 4 unique values, Most common: Morning
#
# Numerical Data Summary:
#        Item_price  connected_handling_time  CSAT Score
# count   38.000000                38.000000   38.000000
# mean   882.289474               383.947368    4.578947
# std    104.077390               144.999711    0.889323
# min    643.000000                45.000000    1.000000
# ...

# %% [markdown]
# #####  To  Create "Resolution_Time" column

# %%
#To create Resolution_Time 
# Check the column names
print(df.columns)
# Out:
# Index(['Unique id', 'channel_name', 'category', 'Sub-category',
#        'Customer Remarks', 'Order_id', 'order_date_time', 'Issue_reported at',
#        'issue_responded', 'Survey_response_Date', 'Customer_City',
#        'Product_category', 'Item_price', 'connected_handling_time',
#        'Agent_name', 'Supervisor', 'Manager', 'Tenure Bucket', 'Agent Shift',
#        'CSAT Score'],
#       dtype='object')

# %%
# Convert datetime columns
df["Issue_reported at"] = pd.to_datetime(df["Issue_reported at"], errors="coerce")
df["issue_responded"] = pd.to_datetime(df["issue_responded"], errors="coerce")

# Compute resolution time in minutes
df["Resolution_Time"] = (df["issue_responded"] - df["Issue_reported at"]).dt.total_seconds() / 60

# Drop rows where Resolution_Time is missing
df = df.dropna(subset=["Resolution_Time"])

# %%
# Verify the new column
print(df[["Issue_reported at", "issue_responded", "Resolution_Time"]].head())
# Out:
#     Issue_reported at     issue_responded  Resolution_Time
# 0 2023-05-08 11:11:00 2023-05-08 11:50:00             39.0
# 1 2023-04-08 12:04:00 2023-05-08 07:02:00          42898.0
# 2 2023-09-08 12:40:00 2023-09-08 12:43:00              3.0
# 3 2023-08-08 12:35:00 2023-08-08 12:39:00              4.0
# 4 2023-07-08 13:55:00 2023-08-08 09:21:00          44366.0

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.
#
# Manipulations Done in Data Wrangling
# 1.Handled Missing Values
#
# Dropped rows with missing values to maintain data integrity.
#
# 2.Converted Date Columns to datetime Format
#
# --Columns converted:
# order_date_time
# Issue_reported at
# issue_responded
# Survey_response_Date
#
# --This helps in time-based analysis.
#
# 3.Optimized Categorical Columns
#
# -Converted categorical columns to category type for better performance.
#
# -Columns optimized:
# --channel_name, category, Sub-category, Customer_City, Product_category, Agent_name, Supervisor, Manager, Tenure Bucket, Agent Shift
#
# 4.Converted Numerical Columns to Proper Data Types
#
# -Ensured numeric columns are correctly formatted for analysis.
# -Columns converted:
# Item_price, connected_handling_time, CSAT Score
#
# 5.Removed Duplicate Records
#
# -Eliminated duplicate rows to avoid redundant data.
#
# 6.Reset Index
#
# -Restructured the dataset by resetting the index after cleaning.
#
# Insights Found
#
# 1. Dataset Structure
# After cleaning:
# Rows: 38
# Columns: 20
#
# 2. Unique Values & Most Common Categories
#
# channel_name: 2 unique values (Most common: Outcall)
#
# category: 3 unique values (Most common: Returns)
#
# Agent_name: 24 unique agents (Most common: Jennifer Perry)
#
# Supervisor: 9 unique supervisors (Most common: Mason Gupta)
#
# Manager: 3 unique managers (Most common: Olivia Tan)
#
# 3. Numerical Data Insights
#
# --Item Price:
#
# Range: ₹643 to ₹999
# Average Price: ₹882
#
# --Connected Handling Time (Call Duration):
#
# Range: 45 to 732 seconds
# Average Handling Time: 384 seconds
#
# --CSAT Score (Customer Satisfaction):
#
# Range: 1 to 5
# Average Score: 4.58 (indicating high customer satisfaction).
#
# Final Thoughts:
#
# -The dataset is now clean and analysis-ready.
#
# -Customer Satisfaction (CSAT) is generally high (avg. 4.58).
#
# -Most reported category is "Returns".
#
# -The longest handling time is 732 seconds (~12 minutes), while the shortest is 45 seconds.
#
# -Common supervisor: "Mason Gupta" and most active agent: "Jennifer Perry".

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1   Countplot of Issues by Category

# %%
# Chart - 1 visualization code
plt.figure(figsize=(12, 6))
sns.countplot(y=df["category"], order=df["category"].value_counts().index, palette="viridis")
plt.title("Count of Issues by Category")
plt.xlabel("Count")
plt.ylabel("Issue Category")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Countplot is the best choice because it visually represents the frequency of issues by category.
#
# ✔ It helps identify the most common issues that customers face.
#
# ✔ Sorting categories by frequency makes it easier to focus on high-impact areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 The most frequent issue categories indicate key problem areas in customer service.
#
# 📌 If a particular category has an exceptionally high count, it may suggest a systematic issue in that area (e.g., repeated payment failures).
#
# 📌 Categories with low counts may either be well-managed or need more customer awareness.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# By identifying the top issues, the company can prioritize fixes, reducing customer complaints and churn.
# If a specific category (e.g., "Payment Issues") is dominant, automating or improving the payment system can enhance customer satisfaction.
#
# ❌ Negative Growth Risks:
#
# If unresolved, high-volume issues can damage brand reputation, leading to lower customer retention.
# A high number of complaints in a critical category (e.g., delivery) could indicate logistics inefficiencies that impact profitability.
#
# Final Justification
#
# ✔ Addressing the most frequent issues will enhance operational efficiency and customer satisfaction (CSAT Scores).
#
# ✔ Insights from this chart can guide strategic decisions, such as hiring more agents for high-volume issues or introducing self-service solutions.

# %% [markdown]
# #### Chart - 2  Distribution of CSAT Scores

# %%
# Chart - 2 visualization code
plt.figure(figsize=(12, 6))
sns.histplot(df["CSAT Score"], bins=5, kde=True, color="blue")
plt.title("Distribution of CSAT Scores")
plt.xlabel("CSAT Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Histogram with KDE (Kernel Density Estimation) is used to analyze the distribution of CSAT (Customer Satisfaction) Scores.
#
# ✔ It helps understand how customer satisfaction is spread—whether it's normally distributed or skewed.
#
# ✔ The binning (5 bins) allows for better visualization of score frequencies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the distribution is left-skewed (most scores are high) → Customers are generally satisfied.
#
# 📌 If the distribution is right-skewed (most scores are low) → Major service issues need attention.
#
# 📌 A bimodal or widely spread distribution suggests mixed experiences among customers—some very happy, others very unhappy.
#
# 📌 A sharp peak at a particular score (e.g., 3) may indicate neutral customer experiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If CSAT scores are mostly high (4-5), it confirms strong customer service performance.
# A well-balanced distribution suggests diverse customer feedback, which can help fine-tune specific areas of service.
#
# ❌ Negative Growth Risks:
#
# If a large number of customers rate 1-2, there may be critical service failures leading to high churn rates.
# If customers mostly rate 3 (neutral), it may indicate lack of strong brand loyalty—meaning customers are not highly engaged.
#
# Final Justification
#
# ✔ High CSAT Scores → Maintain current service quality and reinforce strong areas.
#
# ✔ Low CSAT Scores → Identify problematic touchpoints and take corrective actions (e.g., agent training, faster resolution times).
#
# ✔ This analysis can guide customer experience strategies to improve retention and loyalty.

# %% [markdown]
# #### Chart - 3  HAndling Time Vs. CSAT Score

# %%
# Chart - 3 visualization code
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df["Resolution_Time"], y=df["CSAT Score"], alpha=0.5)
plt.title("Handling Time vs. CSAT Score")
plt.xlabel("Resolution Time (Minutes)")
plt.ylabel("CSAT Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Scatter Plot is ideal for analyzing the relationship between resolution time and customer satisfaction (CSAT Score).
#
# ✔ It helps determine whether faster issue resolution leads to higher satisfaction or if customers are unhappy regardless of response time.
#
# ✔ The alpha (transparency) value of 0.5 prevents overlapping data points from making the plot unreadable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the scatter plot shows a negative trend (longer resolution time → lower CSAT scores), it confirms that delays frustrate customers.
#
# 📌 If there’s no clear pattern, it suggests other factors (e.g., agent quality, issue complexity) impact CSAT more than resolution time.
#
# 📌 A cluster of high CSAT scores at lower resolution times suggests customers appreciate fast responses.
#
# 📌 A spread-out distribution may indicate some complex cases still receive high satisfaction, meaning response quality matters as much as speed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If shorter resolution times correlate with higher CSAT scores, investing in process efficiency (e.g., automation, AI chatbots) will boost satisfaction.
# Identifying a sweet spot (e.g., under 30 minutes) for maintaining high CSAT can help optimize service-level agreements (SLAs).
#
# ❌ Negative Growth Risks:
#
# If CSAT remains low even for fast resolutions, it indicates other pain points, such as poor agent training or issue recurrence.
# If long resolution times don’t always lead to bad CSAT scores, the company must explore whether certain cases require extra time for better resolution.
#
# Final Justification
#
# ✔ If handling time strongly impacts satisfaction, the company should focus on reducing resolution delays.
#
# ✔ If no strong correlation is found, it should investigate other service quality factors (e.g., agent expertise, communication).
#
# ✔ This analysis can guide customer service training, automation, and workflow improvements.

# %% [markdown]
# #### Chart - 4  Issue Resolution Time Distribution

# %%
# Chart - 4 visualization code
plt.figure(figsize=(12, 6))
sns.histplot(df["Resolution_Time"].dropna(), bins=30, kde=True, color="red")
plt.title("Issue Resolution Time Distribution")
plt.xlabel("Resolution Time (Minutes)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Histogram with KDE (Kernel Density Estimation) is the best choice to analyze the distribution of issue resolution times.
#
# ✔ It helps identify patterns in how long it takes to resolve customer issues.
#
# ✔ The 30 bins provide a detailed breakdown while the KDE line shows the overall trend.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the distribution is right-skewed (most issues are resolved quickly, but some take much longer), it indicates a few complex cases delay the average resolution time.
#
# 📌 If there’s a peak at a specific time (e.g., 10 minutes), it suggests a standard resolution benchmark used by the support team.
#
# 📌 A broad or multi-peaked distribution may indicate variability in agent efficiency or issue complexity.
#
# 📌 If resolution times are highly spread out, it means some issues take much longer, possibly due to workflow inefficiencies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If most issues are resolved quickly, it confirms operational efficiency and strong customer service processes.
# If a majority of cases are resolved within an acceptable SLA, it helps build customer trust and satisfaction.
#
# ❌ Negative Growth Risks:
#
# If there are significant delays (long tail in distribution), it suggests bottlenecks in issue resolution, requiring process improvements.
# Inconsistent resolution times can indicate skill gaps among agents, leading to unpredictable customer experiences.
#
# Final Justification
#
# ✔ If resolution times are optimized, focus on maintaining efficiency while improving CSAT.
#
# ✔ If resolution times are inconsistent, explore automation, training, or better triaging of support requests.
#
# ✔ This analysis can guide SLA adjustments, workforce management, and automation strategies.

# %% [markdown]
# #### Chart - 5   Number of Issues per Channel (Bar Chart)

# %%
# Chart - 5 visualization code
plt.figure(figsize=(12, 6))
sns.countplot(y=df["channel_name"], order=df["channel_name"].value_counts().index, palette="coolwarm")
plt.title("Number of Issues per Channel")
plt.xlabel("Count")
plt.ylabel("Channel Name")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Countplot is used to visualize the number of customer issues reported across different channels (e.g., email, phone, chat, social media).
#
# ✔ It helps identify the most and least used support channels.
#
# ✔ The coolwarm palette makes it visually clear which channels handle the highest volume of issues.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If a single channel (e.g., Phone) dominates, it suggests customers prefer that medium for support.
#
# 📌 If multiple channels have similar issue counts, it indicates a balanced multi-channel strategy.
#
# 📌 A low number of issues in some channels may mean customers are either not aware of them or find them inefficient.
#
# 📌 If social media has a high volume, it signals customers increasingly prefer public platforms for complaints.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If the preferred channel has high CSAT scores, it confirms that it is an effective support medium.
# If multiple channels are equally used, the company is successfully offering flexible support options.
#
# ❌ Negative Growth Risks:
#
# If one channel is overloaded while others are underused, it suggests an imbalance in customer service workload, requiring resource reallocation.
# If a channel has high issue volume but low CSAT, it may indicate frustrating customer experiences, requiring process improvements.
#
# Final Justification
#
# ✔ If one channel dominates, optimize it further while exploring automation for efficiency.
#
# ✔ If some channels underperform, investigate awareness, accessibility, and service quality.
#
# ✔ This analysis can guide omnichannel strategies, staffing decisions, and customer experience improvements.

# %% [markdown]
# #### Chart - 6  Top 10 Agents Handling Most Cases (Bar Chart)

# %%
# Chart - 6 visualization code
plt.figure(figsize=(12, 6))
top_agents = df["Agent_name"].value_counts().head(10)
sns.barplot(x=top_agents.values, y=top_agents.index, palette="plasma")
plt.title("Top 10 Agents Handling Most Cases")
plt.xlabel("Number of Cases")
plt.ylabel("Agent Name")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Bar Plot is ideal for showing the top 10 agents who handle the most customer cases.
#
# ✔ It helps identify the most active and high-performing agents.
#
# ✔ The plasma color palette makes the chart visually appealing and easy to interpret.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
# 📌 If a few agents dominate the case volume, it could indicate high efficiency or uneven workload distribution.
#
# 📌 If the workload is evenly distributed, it suggests effective case allocation and balanced agent performance.
#
# 📌 If a top agent has significantly more cases than others, it may mean they are more experienced or have better problem-solving skills.
#
# 📌 If low-ranked agents handle very few cases, it could indicate training gaps, efficiency issues, or recent hires.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# Identifying high-performing agents allows for best practices sharing and leadership opportunities.
# Recognizing overloaded agents helps with better workload balancing to prevent burnout.
#
# ❌ Negative Growth Risks:
#
# Uneven case distribution may lead to burnout of top agents and lower motivation for others.
# If less experienced agents handle fewer cases, they may lack opportunities to improve skills, affecting service quality.
#
# Final Justification
#
# ✔ If workload is unbalanced, redistribute cases to improve efficiency and agent well-being.
#
# ✔ If certain agents excel consistently, consider rewarding and promoting them to leadership roles.
#
# ✔ This analysis can optimize workforce management and improve overall customer service efficiency.

# %% [markdown]
# #### Chart - 7  CSAT Score by Category (Boxplot)

# %%
# Chart - 7 visualization code
plt.figure(figsize=(12, 6))
sns.boxplot(x="CSAT Score", y="category", data=df, palette="muted")
plt.title("CSAT Score by Issue Category")
plt.xlabel("CSAT Score")
plt.ylabel("Issue Category")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Boxplot is ideal for analyzing the distribution of CSAT (Customer Satisfaction) scores across different issue categories.
#
# ✔ It shows median, quartiles, and outliers, helping to identify variation in customer satisfaction for different issues.
#
# ✔ The muted palette ensures clarity in differentiating categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If some categories have consistently high CSAT scores, it means customers are satisfied with how those issues are resolved.
#
# 📌 If certain categories have a lower median CSAT score, it suggests those issues are not being handled well.
#
# 📌 Large spread in a category (big interquartile range) indicates inconsistent service quality.
#
# 📌 Presence of outliers (points far from the main distribution) may signal exceptionally good or poor experiences.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# Identifying high-CSAT categories helps understand strengths and maintain best practices.
# Consistently high scores for an issue type indicate well-trained agents and effective resolution methods.
#
# ❌ Negative Growth Risks:
#
# If certain issue types have low median CSAT scores, they may need process improvement, better agent training, or faster resolution strategies.
# High variance in CSAT within a category suggests inconsistent customer experiences, which can lead to trust issues.
#
# Final Justification
#
# ✔ If certain issue categories perform poorly, analyze their resolution processes and consider additional agent training.
#
# ✔ If some categories consistently get high satisfaction, apply their best practices to other areas.
#
# ✔ This analysis helps target improvements in weak areas, leading to better customer satisfaction overall.

# %% [markdown]
# #### Chart - 8  Handling Time by Category (Violin Plot)

# %%
# Chart - 8 visualization code
plt.figure(figsize=(12, 6))
sns.violinplot(x="category", y="Resolution_Time", data=df, palette="coolwarm", scale="width")
plt.xticks(rotation=90)
plt.title("Handling Time by Category")
plt.xlabel("Issue Category")
plt.ylabel("Resolution Time (Minutes)")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Violin Plot is great for visualizing the distribution of resolution times across different issue categories.
#
# ✔ It combines a boxplot (median, quartiles) with a KDE plot (distribution shape) to show both central tendency and variability.
#
# ✔ The coolwarm palette helps differentiate categories while maintaining clarity.
#
# ✔ The width of each violin represents the density of resolution times, showing which times are most common.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If some categories have a wider distribution, it means resolution times vary significantly, indicating inconsistent service.
#
# 📌 A long tail in any category suggests that some cases take exceptionally long to resolve, which may frustrate customers.
#
# 📌 If a category has a high median resolution time, it likely means those issues are complex or need more resources.
#
# 📌 If a category has a small, compact violin, it means most issues in that category are resolved in a predictable time frame.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If certain issue categories have consistently short resolution times, they can be used as a benchmark for improving slower categories.
# Understanding which categories have stable handling times can help with workload forecasting and resource allocation.
#
# ❌ Negative Growth Risks:
#
# High variability in resolution times within a category means unpredictable service quality, which can frustrate customers.
# Long resolution times for certain issues may indicate a need for better training, process optimization, or automation.
#
# Final Justification
#
# ✔ If some categories take significantly longer to resolve, analyze the reasons and find ways to optimize.
#
# ✔ If resolution times are inconsistent within a category, consider standardizing procedures to improve efficiency.
#
# ✔ This analysis helps reduce long wait times, improve customer experience, and optimize resource allocation

# %% [markdown]
# #### Chart - 9  Issue Response Time vs. CSAT (Scatter Plot with Trend Line)

# %%
# Chart - 9 visualization code
plt.figure(figsize=(12, 6))
sns.regplot(x=df["Resolution_Time"], y=df["CSAT Score"], scatter_kws={"alpha": 0.3}, line_kws={"color": "red"})
plt.title("Response Time vs. CSAT Score")
plt.xlabel("Resolution Time (Minutes)")
plt.ylabel("CSAT Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Regression Plot (regplot) is ideal for analyzing the relationship between Resolution Time and CSAT Score.
#
# ✔ It includes both scatter points (individual cases) and a trend line, which helps visualize whether longer resolution times impact CSAT scores.
#
# ✔ The red regression line provides a clear trend direction.
#
# ✔ Transparency in scatter points helps reduce overplotting and makes dense areas clearer.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the regression line slopes downward, it suggests longer resolution times lead to lower CSAT scores (negative impact).
#
# 📌 If the line is flat, it means handling time does not significantly impact customer satisfaction.
#
# 📌 If there is no clear pattern (random scatter), other factors beyond resolution time may be influencing CSAT scores.
#
# 📌 If outliers exist (very high resolution time but high CSAT score), it means other factors like agent behavior or issue type might affect satisfaction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If shorter resolution times correlate with higher CSAT, efforts can be focused on reducing wait times and improving efficiency.
# Understanding the exact relationship can help optimize resources to balance speed and quality of service.
#
# ❌ Negative Growth Risks:
#
# If longer resolution times significantly reduce CSAT scores, it signals a need for process improvements or better resource allocation.
# If no strong correlation is found, it suggests other factors (e.g., agent professionalism, resolution quality) play a bigger role in customer satisfaction.
#
# Final Justification
#
# ✔ If longer response times lower CSAT, improving efficiency should be a priority to retain customers.
#
# ✔ If CSAT remains high despite long resolution times, then focus should be on enhancing service quality rather than just speed.
#
# ✔ This analysis helps balance response time and service quality, leading to improved customer experience and loyalty.

# %% [markdown]
# #### Chart - 10 Customer Cities with Most Issues (Bar Chart)

# %%
# Chart - 10 visualization code
plt.figure(figsize=(12, 6))
top_cities = df["Customer_City"].value_counts().head(10)
sns.barplot(x=top_cities.values, y=top_cities.index, palette="magma")
plt.title("Top 10 Customer Cities with Most Issues")
plt.xlabel("Number of Issues")
plt.ylabel("City Name")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Bar Chart is the best choice for visualizing categorical data like the number of issues reported per city.
#
# ✔ Sorting cities by issue count helps identify which locations have the highest number of complaints.
#
# ✔ The magma color palette provides a clear visual contrast and enhances readability.
#
# ✔ A horizontal layout improves label readability for city names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If a few cities dominate the issue count, those locations may have higher customer density or operational challenges.
#
# 📌 If certain cities have significantly higher issue reports, service quality, delivery speed, or agent availability in those areas should be reviewed.
#
# 📌 If top cities align with major business hubs, the issue volume may be proportional to the number of customers in those areas.
#
# 📌 If some cities have unexpectedly high issues, it may indicate regional challenges like poor infrastructure, delayed services, or product quality issues.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# Helps allocate customer support resources more effectively to high-issue cities.
# Can identify region-specific challenges and tailor solutions to improve service in problematic locations.
# If high-issue cities are also high-revenue areas, prioritizing improvements there can boost customer loyalty and retention.
#
# ❌ Negative Growth Risks:
#
# If certain cities consistently have high complaints but no improvement efforts, customer dissatisfaction may lead to churn.
# If service issues are regional (e.g., poor logistics in a city), competitors with better service may take market share.
#
# Final Justification
#
# ✔ If certain cities report a high number of complaints, targeted process improvements (e.g., faster response times, better service infrastructure) should be implemented.
#
# ✔ If complaint trends are seasonal or based on external factors, predictive modeling can help anticipate and mitigate future issues.
#
# ✔ This analysis enables strategic resource allocation, improved service quality, and better customer satisfaction in key markets.

# %% [markdown]
# #### Chart - 11  CSAT Score Trend Over Time (Line Chart)

# %%
# Chart - 11 visualization code
plt.figure(figsize=(12, 6))
df["Survey_response_Date"] = pd.to_datetime(df["Survey_response_Date"])
csat_trend = df.groupby(df["Survey_response_Date"].dt.date)["CSAT Score"].mean()
sns.lineplot(x=csat_trend.index, y=csat_trend.values, marker="o", color="green")
plt.title("CSAT Score Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Average CSAT Score")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Line Chart is the best way to visualize trends over time, making it ideal for tracking how customer satisfaction (CSAT Score) changes over different dates.
#
# ✔ The x-axis (Survey Response Date) shows the timeline, while the y-axis (Average CSAT Score) displays customer satisfaction trends.
#
# ✔ Markers ("o") on the line help highlight daily CSAT values, making it easier to spot fluctuations.
#
# ✔ The green color reinforces a positive association with customer satisfaction improvement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the CSAT score trends upward, it indicates improvements in service quality, resolution time, or customer experience.
#
# 📌 If the CSAT score declines, it signals service issues, agent inefficiencies, or customer dissatisfaction.
#
# 📌 If there are sudden drops, they could be linked to specific events (e.g., system downtime, product defects, or policy changes).
#
# 📌 Seasonal trends might appear if CSAT fluctuates during holiday seasons, sales events, or high-demand periods.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# Helps track service performance over time and identify best practices when CSAT scores are high.
# Enables quick response to negative trends by investigating and resolving underlying issues.
# Identifies the effectiveness of past service improvements and guides future enhancements.
#
# ❌ Negative Growth Risks:
#
# If CSAT scores consistently decline without intervention, it could lead to customer churn and brand reputation damage.
# If improvements are inconsistent, it may indicate unstable service quality, requiring deeper investigation.
#
# Final Justification
#
# ✔ This trend analysis helps track customer sentiment over time and allows businesses to proactively address service issues.
#
# ✔ If CSAT scores drop after a specific event, investigating and addressing root causes becomes easier.
#
# ✔ Identifying seasonal patterns enables better resource planning and service optimization during peak times.

# %% [markdown]
# #### Chart - 12  Issue Resolution Time Distribution

# %%
# Chart - 12 visualization code
# Plot histogram for Resolution Time Distribution
plt.figure(figsize=(12, 6))
sns.histplot(df["Resolution_Time"], bins=30, kde=True, color="skyblue")
plt.title("Issue Resolution Time Distribution")
plt.xlabel("Resolution Time (Minutes)")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Histogram is the best chart to visualize the distribution of continuous numerical data, such as Resolution Time.
#
# ✔ It helps identify patterns, outliers, and variations in how long it takes to resolve customer issues.
#
# ✔ The kernel density estimation (KDE) curve overlays a smooth distribution, making it easier to understand trends.
#
# ✔ The "skyblue" color enhances clarity while maintaining a professional look.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the majority of resolution times are clustered on the left, it indicates quick issue resolution, which is a positive sign.
#
# 📌 If the distribution is right-skewed (long tail on the right), it suggests that some issues take significantly longer to resolve, possibly due to complexity or process inefficiencies.
#
# 📌 If there are multiple peaks, different categories of issues may have varying resolution times (e.g., technical issues vs. billing issues).
#
# 📌 Outliers (very high resolution times) may indicate bottlenecks in customer support workflows, requiring process improvements.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# Identifies efficiently handled cases, setting benchmarks for fast resolution.
# Helps streamline support operations by analyzing resolution time trends.
# If resolution times are consistently low, it indicates a well-optimized support system.
#
# ❌ Negative Growth Risks:
#
# If there are frequent long resolution times, customers may become frustrated, leading to lower satisfaction (CSAT) and potential churn.
# Bottlenecks in customer service workflows (e.g., agent overload, system inefficiencies) can cause delays, increasing customer complaints.
#
# Final Justification
#
# ✔ This chart helps pinpoint inefficiencies in issue resolution by analyzing the spread of resolution times.
#
# ✔ If long resolution times affect CSAT scores, the company should optimize processes, introduce automation, or train agents to resolve issues faster.
#
# ✔ If the company wants to improve CSAT, reducing long resolution times should be a priority.

# %% [markdown]
# #### Chart - 13     Handling Time Distribution (Histogram)

# %%
# Chart - 13 visualization code
plt.figure(figsize=(12, 6))
sns.histplot(df["Resolution_Time"], bins=40, kde=True, color="purple")
plt.title("Handling Time Distribution")
plt.xlabel("Resolution Time (Minutes)")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ Histogram is the best way to analyze the distribution of numerical data such as Handling Time (Resolution Time).
#
# ✔ It helps to visualize the spread, skewness, and density of handling times across all customer issues.
#
# ✔ The KDE (Kernel Density Estimation) curve adds a smooth trend line, making it easier to interpret patterns.
#
# ✔ Using 40 bins provides a detailed view of different handling time intervals.
#
# ✔ Purple color ensures good visibility while maintaining a professional look.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 If the majority of resolution times are clustered in a specific range, this suggests a standardized issue resolution process.
#
# 📌 A right-skewed distribution (long tail on the right) indicates that some issues take significantly longer to resolve, possibly due to complexity, inefficiencies, or system delays.
#
# 📌 If the data has multiple peaks, it may suggest different handling times for different categories of issues (e.g., technical issues vs. billing problems).
#
# 📌 Outliers (extremely high resolution times) highlight potential problem areas in customer support operations.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here
#
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# Helps in identifying the efficiency of customer support teams.
# If resolution times are mostly low, it indicates a well-optimized support system.
# Enables data-driven decisions to streamline processes and reduce delays.
#
# ❌ Negative Growth Risks:
#
# If many issues take a long time to resolve, it may lead to customer frustration, lower CSAT scores, and higher churn rates.
# High variation in handling times can indicate inconsistencies in support processes, leading to customer dissatisfaction.
#
# Final Justification
#
# ✔ This chart provides deep insights into handling time trends, helping the company improve service efficiency.
#
# ✔ If long resolution times are frequent, the company should introduce automation, prioritize urgent issues, or provide better agent training.
#
# ✔ If handling times differ significantly by category, then segmenting issues and optimizing support for each type may improve efficiency.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap of Numeric Variables

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10, 6))
sns.heatmap(df[["Item_price", "CSAT Score", "Resolution_Time"]].corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap of Numeric Variables")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ A correlation heatmap is the best way to analyze relationships between numeric variables in a dataset.
#
# ✔ It provides a quick and clear visualization of how different factors (e.g., Item Price, CSAT Score, Resolution Time) influence each other.
#
# ✔ Color coding (coolwarm palette) makes it easy to identify strong positive and negative correlations.
#
# ✔ The annotated values (correlation coefficients) ensure precise interpretation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 CSAT Score vs. Resolution Time:
#
# If the correlation is negative, it suggests that longer resolution times lead to lower customer satisfaction.
# If the correlation is weak or near zero, it means resolution time does not significantly impact CSAT scores.
#
# 📌 Item Price vs. CSAT Score:
#
# A positive correlation indicates that higher-priced items lead to higher satisfaction (possibly due to better product quality or premium customer service).
# A negative correlation suggests that expensive items may cause dissatisfaction, possibly due to high expectations or product issues.
#
# 📌 Item Price vs. Resolution Time:
#
# If positively correlated, it suggests that higher-priced items take longer to resolve issues (possibly due to complexity or VIP service prioritization).
# A negative or weak correlation suggests that resolution time is independent of the item price.

# %% [markdown]
# #### Chart - 15 - Pair Plot of Key Numeric Variables

# %%
# Pair Plot visualization code
sns.pairplot(df[["Item_price", "CSAT Score", "Resolution_Time"]], diag_kind="kde", markers="o")
plt.suptitle("Pairplot of Key Numeric Variables", y=1.02)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.
#
# ✔ A pair plot is an excellent tool for exploring relationships between multiple numeric variables in a dataset.
#
# ✔ It provides scatter plots for each pair of variables and density plots on the diagonal, helping to visualize patterns and correlations.
#
# ✔ This chart is useful for identifying linear relationships, clusters, and potential outliers among key factors like Item Price, CSAT Score, and Resolution Time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 CSAT Score vs. Resolution Time:
#
# If the scatterplot shows a negative trend, it means longer resolution times decrease customer satisfaction.
# A random distribution suggests that resolution time does not significantly impact CSAT scores.
#
# 📌 Item Price vs. CSAT Score:
#
# A positive trend suggests that higher-priced items lead to higher satisfaction.
# A negative trend could indicate that expensive products result in more dissatisfaction, possibly due to higher expectations or poor perceived value.
#
# 📌 Item Price vs. Resolution Time:
#
# If positively correlated, it means higher-priced items take longer to resolve (likely due to complex support requirements).
# If no correlation is observed, it suggests that issue resolution time is independent of the item price.

# %% [markdown]
# #### Chart-16-   CSAT Score vs. Item Price (Bubble Chart)

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df["Item_price"], y=df["CSAT Score"], size=df["Resolution_Time"], alpha=0.5, sizes=(10, 200))
plt.title("CSAT Score vs. Item Price (Bubble Chart)")
plt.xlabel("Item Price")
plt.ylabel("CSAT Score")
plt.show()

# %% [markdown]
# #### 1. Why did you pick the specific chart?¶

# %%
✔ A bubble chart is used when visualizing the relationship between three variables:

X-axis: Item Price
Y-axis: CSAT Score
Bubble Size: Resolution Time
✔ This type of chart helps analyze how customer satisfaction (CSAT Score) changes with Item Price, while also considering the impact of Resolution Time (larger bubbles indicate longer resolution times).

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here
#
# 📌 CSAT Score vs. Item Price:
#
# If a positive trend is observed, it indicates that higher-priced items lead to higher customer satisfaction.
# A negative trend may indicate that expensive items result in more dissatisfaction, possibly due to higher customer expectations.
# If no clear pattern emerges, Item Price might not significantly affect CSAT Scores.
#
# 📌 Bubble Size (Resolution Time Impact):
#
# Larger bubbles suggest that longer resolution times might correlate with lower CSAT Scores.
# If large bubbles mostly appear at low CSAT Scores, it reinforces that slow support negatively impacts customer satisfaction.

# %% [markdown]
# ### 3.Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Business Impact of These Insights
#
# ✅ Positive Impact:
#
# If higher item prices correlate with high CSAT Scores, companies can emphasize premium product offerings.
# If resolution time negatively affects CSAT Scores, businesses should focus on faster issue resolution to improve customer satisfaction.
# Understanding which product categories cause frequent dissatisfaction helps in enhancing quality or support services.
#
# ❌ Negative Growth Risks:
#
# If expensive items result in low satisfaction, businesses should analyze product quality, pricing strategy, or support services.
# Longer resolution times affecting satisfaction negatively could damage brand reputation and lead to customer churn.
#
# Final Justification
#
# ✔ This bubble chart effectively captures three critical business factors (Item Price, CSAT Score, and Resolution Time) in one visual.
#
# ✔ It helps businesses identify pricing and support service issues that influence customer satisfaction.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.
#
# 1️⃣ Reduce Resolution Time to Improve CSAT Scores
#
# 📌 Insight: The scatter plot shows a negative correlation between Resolution Time and CSAT Score—longer resolution times result in lower satisfaction.
#
# ✅ Recommendation:
#
# Implement an AI-driven ticket routing system to assign cases to the best-suited agents.
# Set SLA (Service Level Agreements) for issue resolution times to ensure quick responses.
# Use automation for common queries through chatbots and self-service options.
#
# 2️⃣ Optimize Customer Support Channels
#
# 📌 Insight: Some support channels (email, phone, chat, etc.) may have higher issue volumes and lower CSAT scores.
#
# ✅ Recommendation:
#
# Shift focus to the highest-performing channels to improve efficiency.
# Offer 24/7 live chat support for urgent issues.
# Reduce dependency on slow channels (e.g., email) for high-priority problems.
#
# 3️⃣ Enhance Agent Performance & Training
#
# 📌 Insight: The top 10 agents handle the most cases efficiently, while others may need training.
#
# ✅ Recommendation:
#
# Implement monthly training sessions focusing on customer handling and problem-solving.
# Use performance-based incentives to encourage faster and higher-quality resolutions.
# Monitor real-time agent performance dashboards to identify training needs.
# 4️⃣ Improve Self-Service and Knowledge Base
#
# 📌 Insight: Many repetitive queries lead to increased workload on agents.
#
# ✅ Recommendation:
#
# Build a comprehensive knowledge base (FAQs, guides, video tutorials).
# Introduce an AI-powered chatbot for handling common issues automatically.
# Provide an interactive troubleshooting guide for customers.
#
# 5️⃣ Prioritize High-Value Customer Segments
#
# 📌 Insight: Some customer categories or cities report issues more frequently than others.
#
# ✅ Recommendation:
#
# Provide priority support for high-value customers.
# Assign dedicated account managers to premium customers.
# Implement predictive analytics to proactively resolve issues before customers report them.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.
#
# By implementing these strategies—reducing resolution time, optimizing support channels, improving agent performance, enhancing self-service, and prioritizing key customers—the business can significantly boost customer satisfaction (CSAT), streamline operations, and improve overall efficiency.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***

# %% [markdown]
# ##  ***Thank You***
